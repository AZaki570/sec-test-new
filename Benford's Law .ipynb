# %%
import numpy as np
import pandas as pd 

import benford as bf

# %%
data = pd.read_csv('Desktop/test/10329.csv')

data.head(50)
# Out:
#     0001437749-21-007948  10-Q  5   6  DepreciationDepletionAndAmortization  \
# 0   0001437749-21-007948  10-Q  5   6  DepreciationDepletionAndAmortization
# 1   0001437749-20-020562  10-Q  5   6  DepreciationDepletionAndAmortization
# 2   0001437749-20-020562  10-Q  5   6  DepreciationDepletionAndAmortization
# 3   0001437749-20-020562  10-Q  5   6  DepreciationDepletionAndAmortization
# 4   0001437749-20-020562  10-Q  5   6  DepreciationDepletionAndAmortization
# 5   0001437749-20-014919  10-Q  5   6  DepreciationDepletionAndAmortization
# 6   0001437749-20-014919  10-Q  5   6  DepreciationDepletionAndAmortization
# 7   0001437749-20-014919  10-Q  5   6  DepreciationDepletionAndAmortization
# 8   0001437749-20-014919  10-Q  5   6  DepreciationDepletionAndAmortization
# 9   0001437749-20-006897  10-Q  5   6  DepreciationDepletionAndAmortization
# 10  0001437749-20-006897  10-Q  5   6  DepreciationDepletionAndAmortization
# ...

# %%
data['value'] = data['value'].astype(float)
f1d = bf.first_digits(data['value'], digs=1, confidence=95) # digs=1 for the first digit (1-9)
# Out:
# Initialized sequence with 187 registries.
#
# Test performed on 187 registries.
# Discarded 0 records < 1 after preparation.
#
# The entries with the significant positive deviations are:
#
#              Expected     Found   Z_score
# First_1_Dig
# 3            0.124939  0.187166  2.462966

# %%
data['value'] = data['value'].astype(float)
f3d = bf.second_digit(data['value'], confidence=95) # digs=1 for the first digit (1-9)
# Out:
# Initialized sequence with 187 registries.
#
# Test performed on 187 registries.
# Discarded 0 records < 10 after preparation.
#
# The entries with the significant positive deviations are:
#
#          Expected     Found   Z_score
# Sec_Dig
# 0        0.119679  0.251337  5.434082

# %%
data['value'] = data['value'].astype(float)
f2d = bf.first_digits(data['value'], digs=2, confidence=95) # digs=1 for the first digit (1-9)
# Out:
# Initialized sequence with 187 registries.
#
# Test performed on 187 registries.
# Discarded 0 records < 10 after preparation.
#
# The entries with the significant positive deviations are:
#
#              Expected     Found    Z_score
# First_2_Dig
# 33           0.012965  0.101604  10.391850
# 10           0.041393  0.133690   6.152616
# 22           0.019305  0.053476   3.130302
# 11           0.037789  0.080214   2.850752
# 77           0.005604  0.021390   2.402088
# 66           0.006531  0.021390   2.068755

# %%
data['value'] = data['value'].astype(float)
f3d = bf.first_digits(data['value'], digs=3, confidence=95) # digs=1 for the first digit (1-9)
# Out:
# Initialized sequence with 187 registries.
#
# Test performed on 187 registries.
# Discarded 0 records < 100 after preparation.
#
# The entries with the significant positive deviations are:
#
#              Expected     Found    Z_score
# First_3_Dig
# 338          0.001283  0.032086  10.745764
# 335          0.001294  0.026738   8.659909
# 949          0.000457  0.016043   8.257626
# 340          0.001275  0.021390   6.682492
# 603          0.000720  0.016043   6.450480
# 221          0.001961  0.021390   5.179746
# 992          0.000438  0.010695   4.958800
# 205          0.002113  0.021390   4.944084
# 894          0.000486  0.010695   4.677975
# 120          0.003604  0.026738   4.668868
# 116          0.003728  0.026738   4.563239
# 833          0.000521  0.010695   4.494440
# 795          0.000546  0.010695   4.376276
# 771          0.000563  0.010695   4.300000
# 770          0.000564  0.010695   4.296793
# 103          0.004196  0.026738   4.203060
# ...

# %%
data = pd.read_csv('Desktop/test/38723.csv')

data.head(50)
# Out:
#                     adsh  form  report  line  \
# 0   0001376474-21-000157  10-Q       8     5
# 1   0001376474-21-000157  10-Q       8     5
# 2   0001376474-20-000283  10-Q       8     5
# 3   0001376474-20-000283  10-Q       8     5
# 4   0001376474-20-000195  10-Q       8     5
# 5   0001376474-20-000195  10-Q       8     5
# 6   0001376474-20-000115  10-Q       8     5
# 7   0001376474-20-000115  10-Q       8     5
# 8   0001376474-19-000286  10-Q       8     5
# 9   0001376474-19-000286  10-Q       8     5
# 10  0001376474-19-000126  10-Q       7     5
# 11  0001376474-19-000126  10-Q       7     5
# 12  0001140705-18-000357  10-Q       8     5
# 13  0001140705-18-000357  10-Q       8     5
# 14  0001140705-18-000210  10-Q       8     5
# 15  0001140705-18-000210  10-Q       8     5
# 16  0001140705-18-000116  10-Q       7     5
# 17  0001140705-18-000116  10-Q       7     5
# 18  0001376474-21-000157  10-Q       8    18
# 19  0001376474-21-000157  10-Q       8    18
# ...

# %%
data['value'] = data['value'].astype(float)
f1d = bf.first_digits(data['value'], digs=1, confidence=95) # digs=1 for the first digit (1-9)
# Out:
# Initialized sequence with 82 registries.
#
# Test performed on 82 registries.
# Discarded 0 records < 1 after preparation.
#
# The entries with the significant positive deviations are:
#
# Empty DataFrame
# Columns: [Expected, Found, Z_score]
# Index: []

# %%
data['value'] = data['value'].astype(float)
f2d = bf.second_digit(data['value'], confidence=95) # digs=1 for the first digit (1-9)
# Out:
# Initialized sequence with 82 registries.
#
# Test performed on 82 registries.
# Discarded 0 records < 10 after preparation.
#
# The entries with the significant positive deviations are:
#
#          Expected     Found  Z_score
# Sec_Dig
# 8         0.08757  0.158537   2.0781

# %%
data = pd.read_csv('Desktop/test/52988.csv')

data.head(50)
# Out:
#                     adsh  form  report  line  \
# 0   0000052988-20-000050  10-Q       8    31
# 1   0000052988-20-000050  10-Q       8    31
# 2   0000052988-20-000033  10-Q       8    29
# 3   0000052988-20-000033  10-Q       8    29
# 4   0000052988-20-000019  10-Q       6    22
# 5   0000052988-20-000019  10-Q       6    22
# 6   0000052988-19-000053  10-Q       6    23
# 7   0000052988-19-000053  10-Q       6    23
# 8   0000052988-19-000031  10-Q       6    21
# 9   0000052988-19-000031  10-Q       6    21
# 10  0000052988-19-000008  10-Q       6    21
# 11  0000052988-19-000008  10-Q       6    21
# 12  0000052988-20-000019  10-Q       6    28
# 13  0000052988-20-000019  10-Q       6    28
# 14  0000052988-19-000053  10-Q       6    32
# 15  0000052988-19-000053  10-Q       6    32
# 16  0000052988-21-000016  10-Q       8    23
# 17  0000052988-21-000016  10-Q       8    23
# 18  0000052988-20-000050  10-Q       8    22
# 19  0000052988-20-000050  10-Q       8    22
# ...

# %%
data['value'] = data['value'].astype(float)
f1d = bf.first_digits(data['value'], digs=1, confidence=95) # digs=1 for the first digit (1-9)
# Out:
# Initialized sequence with 158 registries.
#
# Test performed on 158 registries.
# Discarded 0 records < 1 after preparation.
#
# The entries with the significant positive deviations are:
#
#              Expected     Found   Z_score
# First_1_Dig
# 3            0.124939  0.202532  2.829431
# 2            0.176091  0.240506  2.021296

# %%
data['value'] = data['value'].astype(float)
f2d = bf.second_digit(data['value'], confidence=95) # digs=1 for the first digit (1-9)
# Out:
# Initialized sequence with 158 registries.
#
# Test performed on 158 registries.
# Discarded 0 records < 10 after preparation.
#
# The entries with the significant positive deviations are:
#
# Empty DataFrame
# Columns: [Expected, Found, Z_score]
# Index: []
